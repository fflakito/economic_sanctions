# %%
# import required libraries

from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier

pd.set_option('display.max_columns', 80)
sns.set_style("whitegrid")
# %matplotlib inline

np.random.seed(0)

# %%
base_df = pd.read_csv("input/sanctions.csv.gz", index_col=0)

# %%
base_df.columns
new_names = [
    'Sender1', 'Sender2', 'Sender3', 'Target', 'Goal', 'US case',
    'US unilateral case', 'Foreign policy goal category', 'First year',
    'Last year','Policy result', 'Sanctions contribution',
    'Success', 'Companion policies', 'International cooperation',
    'International assistance', 'Cooperating international organization',
    'International organization sender',
    'International organization sender & target members',
    'Length', 'Prior relations',
    'Regime Type1', 'Regime Type2',
    'Regime Type3', 'Political stability prior',
    "Political stability during", 'Cost to targetz',
    'Cost to target (percent of GNP)aa', 'Cost to target per capitabb',
    'Trade linkage', 'GNP ratio','Health and stability',
    'Sanction type', 'Cost to sendergg',
    'GDP growth',
    'Inflation',
    'Target IMF code',
     'Country group']
name_dict = dict(zip(base_df.columns, new_names))
base_df = base_df.rename(columns=name_dict)

# %%
base_df
# Out:
#                      Sender1         Sender2 Sender3       Target  \
# Case no.b
# 14-1          UNITED KINGDOM             NaN     NaN      GERMANY
# 17-1           UNITED STATES             NaN     NaN        JAPAN
# 18-1          UNITED KINGDOM             NaN     NaN       RUSSIA
# 21-1       LEAGUE OF NATIONS             NaN     NaN   YUGOSLAVIA
# 25-1       LEAGUE OF NATIONS             NaN     NaN       GREECE
# ...                      ...             ...     ...          ...
# 98-3                  TURKEY             NaN     NaN        ITALY
# 99-1          UNITED NATIONS   UNITED STATES     NaN  AFGHANISTAN
# 99-2           UNITED STATES  EUROPEAN UNION  FRANCE  IVORY COAST
# 99-3           UNITED STATES           JAPAN     NaN     PAKISTAN
# 00-1           UNITED STATES             NaN     NaN      ECUADOR
#
#                                       Goal  US case  US unilateral case  \
# Case no.b
# 14-1                      Military victory        0                   0
# 17-1                   Shipping for Allies        1                   1
# 18-1                Destabilize Bolsheviks        0                   0
# 21-1       Military disruption vs. Albania        0                   0
# 25-1                Withdraw from Bulgaria        0                   0
# ...                                    ...      ...                 ...
# 98-3                        Kurdish leader        0                   0
# 99-1             Extradite Osama bin Laden        1                   0
# 99-2                       Coup, democracy        1                   0
# 99-3                       Coup, democracy        1                   0
# 00-1                                  Coup        1                   0
#
#            Foreign policy goal category  First year Last year  Policy result  \
# Case no.b
# 14-1                                  4        1914      1918              4
# 17-1                                  5        1917      1918              2
# 18-1                                  2        1918      1920              1
# 21-1                                  3        1921      1921              4
# 25-1                                  3        1925      1925              4
# ...                                 ...         ...       ...            ...
# 98-3                                  1        1998      1999              3
# 99-1                                  1        1999      2002              1
# 99-2                                  2        1999      2002              2
# 99-3                                  2        1999      2001              1
# 00-1                                  2        2000      2000              3
#
#            Sanctions contribution  Success Companion policies  \
# Case no.b
# 14-1                            3       12                  R
# 17-1                            2        4                 --
# 18-1                            2        2                R,Q
# 21-1                            4       16                 --
# 25-1                            4       16                 --
# ...                           ...      ...                ...
# 98-3                            3        9                 --
# 99-1                            2        2                  R
# 99-2                            3        6                 --
# 99-3                            2        2                 --
# 00-1                            4       12                 --
#
#            International cooperation International assistance  \
# Case no.b
# 14-1                               4                        A
# 17-1                               1                       --
# 18-1                               4                       --
# 21-1                               4                       --
# 25-1                               4                       --
# ...                              ...                      ...
# 98-3                               1                       --
# 99-1                               4                       --
# 99-2                               2                       --
# 99-3                               2                       --
# 00-1                               3                       --
#
#           Cooperating international organization  \
# Case no.b
# 14-1                                          --
# 17-1                                          --
# 18-1                                          --
# 21-1                                          --
# 25-1                                          --
# ...                                          ...
# 98-3                                          --
# 99-1                                          --
# 99-2                                 ECOWAS, OAU
# 99-3                            EU, Commonwealth
# 00-1                                         OAS
#
#            International organization sender  \
# Case no.b
# 14-1                                       0
# 17-1                                       0
# 18-1                                       0
# 21-1                                       1
# 25-1                                       1
# ...                                      ...
# 98-3                                       0
# 99-1                                       1
# 99-2                                       1
# 99-3                                       0
# 00-1                                       0
#
#            International organization sender & target members  Length  \
# Case no.b
# 14-1                                                       0        4
# 17-1                                                       0        1
# 18-1                                                       0        2
# 21-1                                                       1        1
# 25-1                                                       1        1
# ...                                                      ...      ...
# 98-3                                                       0        1
# 99-1                                                       1        3
# 99-2                                                       1        3
# 99-3                                                       1        2
# 00-1                                                       1        1
#
#            Prior relations Regime Type1 Regime Type2 Regime Type3  \
# Case no.b
# 14-1                     1            5            2            2
# 17-1                     2            5            1            2
# 18-1                     1            1           -1            2
# 21-1                     2            3            0            2
# 25-1                     2            0           -6            1
# ...                    ...          ...          ...          ...
# 98-3                     3           10           10            3
# 99-1                     1            0           -7            1
# 99-2                     3          -88           -1            2
# 99-3                     2            0           -6            1
# 00-1                     3            6            6            3
#
#           Political stability prior Political stability during  \
# Case no.b
# 14-1                            0,0                        0,0
# 17-1                            0,0                        0,0
# 18-1                            0,1                        0,0
# 21-1                            0,4                        0,0
# 25-1                            0,9                        0,0
# ...                             ...                        ...
# 98-3                            0,0                        0,0
# 99-1                            0,5                        0,3
# 99-2                            0,1                        0,3
# 99-3                            0,1                        0,0
# 00-1                            0,1                        0,0
#
#           Cost to targetz Cost to target (percent of GNP)aa  \
# Case no.b
# 14-1                  843                               7,1
# 17-1                   23                               0,8
# 18-1                  446                               4,1
# 21-1                   --                                --
# 25-1                   --                                --
# ...                   ...                               ...
# 98-3                   --                                --
# 99-1                 33,4                               1,1
# 99-2                   40                               0,3
# 99-3                0,001                             0,001
# 00-1                   --                                --
#
#           Cost to target per capitabb Trade linkage GNP ratio  \
# Case no.b
# 14-1                            12,58             9         1
# 17-1                             0,44          20,5        13
# 18-1                             2,49          18,5         1
# 21-1                               --          26,5        37
# 25-1                               --            36        56
# ...                               ...           ...       ...
# 98-3                               --           1,4      0,16
# 99-1                             1,67           100      5939
# 99-2                             2,50            54      1408
# 99-3                            0,001            20       232
# 00-1                               --            34       614
#
#            Health and stability Sanction type  Cost to sendergg GDP growth  \
# Case no.b
# 14-1                          3         F,X,M                 4        3,6
# 17-1                          3             X                 2        5,4
# 18-1                          1         F,X,M                 3       n.a.
# 21-1                          2            --                 2       -1,5
# 25-1                          2            --                 2        3,3
# ...                         ...           ...               ...        ...
# 98-3                          3            --                 2        1,5
# 99-1                          1         F,X,M                 2        8,2
# 99-2                          1             F                 1        5,2
# 99-3                          1             F                 1        3,4
# 00-1                          1            --                 2        0,8
#
#           Inflation Target IMF code  Country group
# Case no.b
# 14-1            2,9             134              1
# 17-1           25,6             158              1
# 18-1           n.a.             922              2
# 21-1           n.a.             188              2
# 25-1           48,8             174              1
# ...             ...             ...            ...
# 98-3            3,7             136              1
# 99-1           n.a.             512              5
# 99-2            3,7             662              6
# 99-3            9,3             564              5
# 00-1           39,6             248              3
#
# [204 rows x 38 columns]
